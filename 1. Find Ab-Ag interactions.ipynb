# %%
import os
import re
import json
import pandas as pd
from Bio.PDB import *
from Bio import SeqIO
import nglview as nv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from biofunctions.biofunctions import *
pd.set_option('display.max_columns', 100)

# %% [markdown]
# **The objective of this notebook is to obtain the Ab-Ag residues that are part of the paratope-epitope interaction.**
#
# **This interaction is defined by two parameters:**
# 1. The distance from the **CA** of the Ab and Ag residues is less that **max_dist**
# 2. The Number of Ag residues that are considered to be in contact to a given Ab residue in a CDR is defined by **n_closest_ress**.

# %% [markdown]
# # 1. Load metadata and amino acids dictionary

# %% [markdown]
# ## 1.1 Load summary file with the metadata

# %%
metadata = pd.read_csv('sabdab-data/20221001_0807534_summary.tsv', sep='\t')
len(metadata.pdb.unique())
# Out:
# 740

# %% [markdown]
# # 1.2 Filter out non-protein antigens
#
# After inspecting the metadata table, this is the list of antigen types:
# * nan
# * 'peptide'
# * 'Hapten'
# * 'protein'
# * 'protein | protein'
# * 'carbohydrate | protein'
# * 'nucleic-acid'
# * 'carbohydrate'
# * 'carbohydrate | protein | protein'
# * 'protein | peptide'
# * 'nucleic-acid | nucleic-acid | nucleic-acid'
# * 'peptide | peptide | peptide'
#
# Therefore we only keep the ones that have a peptide or a protein

# %%
metadata.antigen_type.unique()
# Out:
# array([nan, 'peptide', 'Hapten', 'protein', 'protein | protein',
#        'carbohydrate | protein', 'nucleic-acid', 'carbohydrate',
#        'carbohydrate | protein | protein', 'protein | peptide',
#        'nucleic-acid | nucleic-acid | nucleic-acid',
#        'peptide | peptide | peptide'], dtype=object)

# %%
filter_out = ['Hapten',
              'nucleid-acid',
              'carbohydrate',
              'nucleic-acid | nucleic-acid | nucleic-acid']
metadata = metadata[~metadata['antigen_type'].isin(filter_out)]
len(metadata.pdb.unique())
# Out:
# 646

# %% [markdown]
# ## 1.3 Load amino acids dictionary

# %%
with open('amino_acids.json','r') as f:
    amino_acids_dict = json.load(f)

# %% [markdown]
# # 2. Get Ab-Ag residue distances
# From every PDB calculate the distance between the alpha carbon (CA) of the Ab residues in CDR regions and the CA of every Ag residue, but keep only those under 15 Angstroms (Å). 15Å was chosen because, based on previous data exploration. It is believed that paratope-epitope interactions occur within this distance.

# %% [markdown]
# ## 2.1 Get PDB IDs

# %%
pdb_ids = metadata.pdb.unique()
len(pdb_ids)
# Out:
# 646

# %% [markdown]
# ## 2.2 Calculate distances and keep distances under 15Å

# %% [markdown]
# Some terms:
# * **n_closest_ag_ress:** How many Ag residues are considered close to any given CDR Ab residue
# * **seqid:** The sequence id of the Ab and AG residues given by the IMGT numbering system.
# * **pdb_dict:** Dictionary with the informacion of the closest Ab-Ag residues. I has de following information
#     * pdbs: a dictionary key
#         * pdb: a pdb id
#             * interactions_dict: one of the outputs of get_closest_ress() function

# %%
n_closest_ag_ress = 6
max_dist = 15
count = 1
pdb_dict = {'pdbs':{}}

#PDBs that can't be processed because an error occurs. Will be added later to the analysis
pending_pdbs = {'pdb':[],'error':[]} 
lambda_func = lambda df: df.nlargest(n_closest_ag_ress, columns='distance')
for pdb in pdb_ids:
    print(f'{count}.- Analyzing pdb {pdb}')
    
    if pdb not in pdb_dict['pdbs']:
        pdb_dict['pdbs'][pdb] = {}
        
    # Parse pdb
    pdb_parser = PDBParser()
    structure = pdb_parser.get_structure(pdb, f'sabdab-data/imgt/{pdb}.pdb')

    # Get chains
    chain_label_list = []
    for model in structure.get_models():
        for chain in model.get_chains():
            chain_label_list.append(chain.get_id())

    # Find all labels given to the Heavy and Light chains in the PDB
    H_labels = list(metadata[(metadata['pdb']==pdb)&(~metadata.Hchain.isna())].Hchain.values)
    L_labels = list(metadata[(metadata['pdb']==pdb)&(~metadata.Lchain.isna())].Lchain.values)

    Ab_labels = H_labels + L_labels
    
    # Find all labels given to the Antigen in the PDB
    if not metadata[(metadata['pdb']==pdb)&(~metadata.antigen_chain.isnull())].empty:
        Ag_labels = list(metadata[metadata['pdb']==pdb].antigen_chain.values)

        if len(Ag_labels) == 1:
            Ag_labels = re.findall('[A-Z]',Ag_labels[0])

    else:
        Ag_labels = []

        for label in chain_label_list:

            if label not in H_labels and label not in L_labels:
                Ag_labels.append(label)
         
    try:
        closest_ress_dict, interactions_dict = get_closest_ress(
                model, Ab_labels, Ag_labels, 
                max_dist, amino_acids_dict)
        
        pdb_dict['pdbs'][pdb] = interactions_dict

        temp_df = pd.DataFrame(closest_ress_dict)

        if temp_df.empty:
            print(f'Empty temp_df with pdb {pdb}')

        else:
            temp_df['ab_ress_seqid'] = temp_df.ab_res + '-' + temp_df.ab_seqid.astype(str)
            temp_df['ag_ress_seqid'] = temp_df.ag_res + '-' + temp_df.ag_seqid.astype(str)
            closest_ress_df = temp_df.groupby('ab_ress_seqid').apply(lambda_func).reset_index(level=[0,1], 
                    drop=True)
            closest_ress_df.sort_values(['ab_ress_seqid','distance','ag_ress_seqid'],inplace=True)
            closest_ress_df['pdb'] = pdb
            
            if not os.path.exists('closest_residues.csv'):
                closest_ress_df.to_csv('closest_residues.csv',index=False)
            else:
                closest_ress_df.to_csv('closest_residues.csv',mode='a',index=False,header=False)
    
    except Exception as e:
        del pdb_dict['pdbs'][pdb]
        pending_pdbs['pdb'].append(pdb)
        pending_pdbs['error'].append(e)
        print(e)

    print('\n')
    if count%50 == 0:
        print(f'Analyzed {count} PDBs so far.')
    count += 1

with open('pdb_dict.json','w') as f:
    json.dump(pdb_dict,f)
    
pending_pdbs_df = pd.DataFrame(pending_pdbs)
pending_pdbs_df.to_csv('pending_pdbs.csv')

all_closest_ress_df = pd.read_csv('closest_residues.csv')
all_closest_ress_df = all_closest_ress_df.sort_values(['pdb','ab_label','ab_seqid','ag_label','ag_seqid'])
all_closest_ress_df.to_csv('closest_residues.csv',index=False)
# Out:
# 1.- Analyzing pdb 1mhh
# 0 total comparisons
# Finished processing pdb.
# Empty temp_df with pdb 1mhh
#
#
# 2.- Analyzing pdb 1hh9
# 100 comparisons made so far.
# 200 comparisons made so far.
# 268 total comparisons
# Finished processing pdb.
#
#
# 3.- Analyzing pdb 2r56
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1090 total comparisons
# Finished processing pdb.
#
#
# 4.- Analyzing pdb 5wux
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1305 total comparisons
# Finished processing pdb.
#
#
# 5.- Analyzing pdb 4xi5
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 518 total comparisons
# Finished processing pdb.
#
#
# 6.- Analyzing pdb 4k9e
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 604 total comparisons
# Finished processing pdb.
#
#
# 7.- Analyzing pdb 4k94
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1098 total comparisons
# Finished processing pdb.
#
#
# 8.- Analyzing pdb 1jps
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 633 total comparisons
# Finished processing pdb.
#
#
# 9.- Analyzing pdb 6h0e
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 828 total comparisons
# Finished processing pdb.
#
#
# 10.- Analyzing pdb 1iqd
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 493 total comparisons
# Finished processing pdb.
#
#
# 11.- Analyzing pdb 4gxu
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2700 comparisons made so far.
# 2800 comparisons made so far.
# 2900 comparisons made so far.
# 3000 comparisons made so far.
# 3100 comparisons made so far.
# 3200 comparisons made so far.
# 3300 comparisons made so far.
# 3400 comparisons made so far.
# 3500 comparisons made so far.
# 3600 comparisons made so far.
# 3700 comparisons made so far.
# 3800 comparisons made so far.
# 3900 comparisons made so far.
# 3916 total comparisons
# Finished processing pdb.
#
#
# 12.- Analyzing pdb 6h06
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 780 total comparisons
# Finished processing pdb.
#
#
# 13.- Analyzing pdb 3uzq
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 604 total comparisons
# Finished processing pdb.
#
#
# 14.- Analyzing pdb 3uze
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 904 total comparisons
# Finished processing pdb.
#
#
# 15.- Analyzing pdb 4jpk
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 442 total comparisons
# Finished processing pdb.
#
#
# 16.- Analyzing pdb 4aei
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1743 total comparisons
# Finished processing pdb.
#
#
# 17.- Analyzing pdb 4idj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 621 total comparisons
# Finished processing pdb.
#
#
# 18.- Analyzing pdb 1dqj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 581 total comparisons
# Finished processing pdb.
#
#
# 19.- Analyzing pdb 5jq6
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 709 total comparisons
# Finished processing pdb.
#
#
# 20.- Analyzing pdb 4eig
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 478 total comparisons
# Finished processing pdb.
#
#
# 21.- Analyzing pdb 4eiz
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 968 total comparisons
# Finished processing pdb.
#
#
# 22.- Analyzing pdb 5t6l
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 947 total comparisons
# Finished processing pdb.
#
#
# 23.- Analyzing pdb 5t6p
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 392 total comparisons
# Finished processing pdb.
#
#
# 24.- Analyzing pdb 4m1g
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 640 total comparisons
# Finished processing pdb.
#
#
# 25.- Analyzing pdb 4m1d
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 712 total comparisons
# Finished processing pdb.
#
#
# 26.- Analyzing pdb 1zv5
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 410 total comparisons
# Finished processing pdb.
#
#
# 27.- Analyzing pdb 4etq
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1275 total comparisons
# Finished processing pdb.
#
#
# 28.- Analyzing pdb 6cmg
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 769 total comparisons
# Finished processing pdb.
#
#
# 29.- Analyzing pdb 5nh3
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1239 total comparisons
# Finished processing pdb.
#
#
# 30.- Analyzing pdb 4pgj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 923 total comparisons
# Finished processing pdb.
#
#
# 31.- Analyzing pdb 1zvy
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 500 total comparisons
# Finished processing pdb.
#
#
# 32.- Analyzing pdb 4qci
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 943 total comparisons
# Finished processing pdb.
#
#
# 33.- Analyzing pdb 5mi0
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 516 total comparisons
# Finished processing pdb.
#
#
# 34.- Analyzing pdb 3lrh
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1067 total comparisons
# Finished processing pdb.
#
#
# 35.- Analyzing pdb 5boz
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2700 comparisons made so far.
# 2800 comparisons made so far.
# 2900 comparisons made so far.
# 3000 comparisons made so far.
# 3100 comparisons made so far.
# 3200 comparisons made so far.
# 3300 comparisons made so far.
# 3400 comparisons made so far.
# 3500 comparisons made so far.
# 3600 comparisons made so far.
# 3700 comparisons made so far.
# 3800 comparisons made so far.
# 3900 comparisons made so far.
# 3968 total comparisons
# Finished processing pdb.
#
#
# 36.- Analyzing pdb 5bo1
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1217 total comparisons
# Finished processing pdb.
#
#
# 37.- Analyzing pdb 5hys
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1008 total comparisons
# Finished processing pdb.
#
#
# 38.- Analyzing pdb 5gkr
# ' DT'
#
#
# 39.- Analyzing pdb 1ri8
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 420 total comparisons
# Finished processing pdb.
#
#
# 40.- Analyzing pdb 1mlc
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1075 total comparisons
# Finished processing pdb.
#
#
# 41.- Analyzing pdb 5fcu
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 589 total comparisons
# Finished processing pdb.
#
#
# 42.- Analyzing pdb 4leo
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 584 total comparisons
# Finished processing pdb.
#
#
# 43.- Analyzing pdb 5wi9
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1591 total comparisons
# Finished processing pdb.
#
#
# 44.- Analyzing pdb 5te4
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 551 total comparisons
# Finished processing pdb.
#
#
# 45.- Analyzing pdb 5te7
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 510 total comparisons
# Finished processing pdb.
#
#
# 46.- Analyzing pdb 6blh
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 447 total comparisons
# Finished processing pdb.
#
#
# 47.- Analyzing pdb 6bli
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2307 total comparisons
# Finished processing pdb.
#
#
# 48.- Analyzing pdb 5d8j
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 576 total comparisons
# Finished processing pdb.
#
#
# 49.- Analyzing pdb 6eyo
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1378 total comparisons
# Finished processing pdb.
#
#
# 50.- Analyzing pdb 3iet
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 383 total comparisons
# Finished processing pdb.
#
#
# Analyzed 50 PDBs so far.
# 51.- Analyzing pdb 3uaj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1154 total comparisons
# Finished processing pdb.
#
#
# 52.- Analyzing pdb 2uzi
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 473 total comparisons
# Finished processing pdb.
#
#
# 53.- Analyzing pdb 3hi1
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1359 total comparisons
# Finished processing pdb.
#
#
# 54.- Analyzing pdb 3hi6
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1139 total comparisons
# Finished processing pdb.
#
#
# 55.- Analyzing pdb 1pz5
# 100 comparisons made so far.
# 200 comparisons made so far.
# 270 total comparisons
# Finished processing pdb.
#
#
# 56.- Analyzing pdb 5j56
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 612 total comparisons
# Finished processing pdb.
#
#
# 57.- Analyzing pdb 5j57
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 359 total comparisons
# Finished processing pdb.
#
#
# 58.- Analyzing pdb 5hdq
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 524 total comparisons
# Finished processing pdb.
#
#
# 59.- Analyzing pdb 4uu9
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 754 total comparisons
# Finished processing pdb.
#
#
# 60.- Analyzing pdb 6d01
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2658 total comparisons
# Finished processing pdb.
#
#
# 61.- Analyzing pdb 1nca
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 636 total comparisons
# Finished processing pdb.
#
#
# 62.- Analyzing pdb 4o4y
# 100 comparisons made so far.
# 200 comparisons made so far.
# 202 total comparisons
# Finished processing pdb.
#
#
# 63.- Analyzing pdb 1fsk
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2476 total comparisons
# Finished processing pdb.
#
#
# 64.- Analyzing pdb 1p2c
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1117 total comparisons
# Finished processing pdb.
#
#
# 65.- Analyzing pdb 3wd5
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 465 total comparisons
# Finished processing pdb.
#
#
# 66.- Analyzing pdb 4rdq
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2700 comparisons made so far.
# 2800 comparisons made so far.
# 2900 comparisons made so far.
# 3000 comparisons made so far.
# 3085 total comparisons
# Finished processing pdb.
#
#
# 67.- Analyzing pdb 4ypg
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1746 total comparisons
# Finished processing pdb.
#
#
# 68.- Analyzing pdb 5nqw
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 581 total comparisons
# Finished processing pdb.
#
#
# 69.- Analyzing pdb 2ybr
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1571 total comparisons
# Finished processing pdb.
#
#
# 70.- Analyzing pdb 1bj1
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1058 total comparisons
# Finished processing pdb.
#
#
# 71.- Analyzing pdb 4h88
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 381 total comparisons
# Finished processing pdb.
#
#
# 72.- Analyzing pdb 4hs8
# 100 comparisons made so far.
# 200 comparisons made so far.
# 296 total comparisons
# Finished processing pdb.
#
#
# 73.- Analyzing pdb 3uc0
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1106 total comparisons
# Finished processing pdb.
#
#
# 74.- Analyzing pdb 1f90
# 100 comparisons made so far.
# 200 comparisons made so far.
# 255 total comparisons
# Finished processing pdb.
#
#
# 75.- Analyzing pdb 2jel
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 565 total comparisons
# Finished processing pdb.
#
#
# 76.- Analyzing pdb 4mhh
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1592 total comparisons
# Finished processing pdb.
#
#
# 77.- Analyzing pdb 4mhj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2700 comparisons made so far.
# 2800 comparisons made so far.
# 2838 total comparisons
# Finished processing pdb.
#
#
# 78.- Analyzing pdb 5mes
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 519 total comparisons
# Finished processing pdb.
#
#
# 79.- Analyzing pdb 5e8d
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 511 total comparisons
# Finished processing pdb.
#
#
# 80.- Analyzing pdb 5e8e
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 326 total comparisons
# Finished processing pdb.
#
#
# 81.- Analyzing pdb 5j3h
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 554 total comparisons
# Finished processing pdb.
#
#
# 82.- Analyzing pdb 4yk4
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1059 total comparisons
# Finished processing pdb.
#
#
# 83.- Analyzing pdb 4jzj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1150 total comparisons
# Finished processing pdb.
#
#
# 84.- Analyzing pdb 6d6t
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 970 total comparisons
# Finished processing pdb.
#
#
# 85.- Analyzing pdb 6d6u
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 971 total comparisons
# Finished processing pdb.
#
#
# 86.- Analyzing pdb 5c6t
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 321 total comparisons
# Finished processing pdb.
#
#
# 87.- Analyzing pdb 4hpy
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 327 total comparisons
# Finished processing pdb.
#
#
# 88.- Analyzing pdb 5bk1
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1612 total comparisons
# Finished processing pdb.
#
#
# 89.- Analyzing pdb 4iof
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 712 total comparisons
# Finished processing pdb.
#
#
# 90.- Analyzing pdb 2vis
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 596 total comparisons
# Finished processing pdb.
#
#
# 91.- Analyzing pdb 2vir
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 600 total comparisons
# Finished processing pdb.
#
#
# 92.- Analyzing pdb 3ggw
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 490 total comparisons
# Finished processing pdb.
#
#
# 93.- Analyzing pdb 2p46
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 848 total comparisons
# Finished processing pdb.
#
#
# 94.- Analyzing pdb 2p44
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 432 total comparisons
# Finished processing pdb.
#
#
# 95.- Analyzing pdb 2xtj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 584 total comparisons
# Finished processing pdb.
#
#
# 96.- Analyzing pdb 4liq
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 357 total comparisons
# Finished processing pdb.
#
#
# 97.- Analyzing pdb 3w2d
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 360 total comparisons
# Finished processing pdb.
#
#
# 98.- Analyzing pdb 4wem
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 523 total comparisons
# Finished processing pdb.
#
#
# 99.- Analyzing pdb 4wen
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 493 total comparisons
# Finished processing pdb.
#
#
# 100.- Analyzing pdb 4weu
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 763 total comparisons
# Finished processing pdb.
#
#
# Analyzed 100 PDBs so far.
# 101.- Analyzing pdb 6cwt
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1271 total comparisons
# Finished processing pdb.
#
#
# 102.- Analyzing pdb 5dd0
# 100 comparisons made so far.
# 200 comparisons made so far.
# 259 total comparisons
# Finished processing pdb.
#
#
# 103.- Analyzing pdb 6ii8
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1800 total comparisons
# Finished processing pdb.
#
#
# 104.- Analyzing pdb 6ii9
# 'CA'
#
#
# 105.- Analyzing pdb 6ii4
# 'CA'
#
#
# 106.- Analyzing pdb 5bvp
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 643 total comparisons
# Finished processing pdb.
#
#
# 107.- Analyzing pdb 3uzv
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 586 total comparisons
# Finished processing pdb.
#
#
# 108.- Analyzing pdb 3ngb
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2040 total comparisons
# Finished processing pdb.
#
#
# 109.- Analyzing pdb 5o0w
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2229 total comparisons
# Finished processing pdb.
#
#
# 110.- Analyzing pdb 5j13
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 365 total comparisons
# Finished processing pdb.
#
#
# 111.- Analyzing pdb 4al8
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 349 total comparisons
# Finished processing pdb.
#
#
# 112.- Analyzing pdb 5c0n
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 690 total comparisons
# Finished processing pdb.
#
#
# 113.- Analyzing pdb 3eba
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 'CA'
#
#
# 114.- Analyzing pdb 5c0s
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 449 total comparisons
# Finished processing pdb.
#
#
# 115.- Analyzing pdb 3e8u
# 'CA'
#
#
# 116.- Analyzing pdb 4dn4
# 100 comparisons made so far.
# 200 comparisons made so far.
# 296 total comparisons
# Finished processing pdb.
#
#
# 117.- Analyzing pdb 2hfg
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 544 total comparisons
# Finished processing pdb.
#
#
# 118.- Analyzing pdb 4am0
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1239 total comparisons
# Finished processing pdb.
#
#
# 119.- Analyzing pdb 4kze
# '  G'
#
#
# 120.- Analyzing pdb 1h8s
# 'CA'
#
#
# 121.- Analyzing pdb 5tkj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 970 total comparisons
# Finished processing pdb.
#
#
# 122.- Analyzing pdb 5tkk
# 100 comparisons made so far.
# 200 comparisons made so far.
# 224 total comparisons
# Finished processing pdb.
#
#
# 123.- Analyzing pdb 2i60
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 983 total comparisons
# Finished processing pdb.
#
#
# 124.- Analyzing pdb 2y6s
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 727 total comparisons
# Finished processing pdb.
#
#
# 125.- Analyzing pdb 3be1
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 480 total comparisons
# Finished processing pdb.
#
#
# 126.- Analyzing pdb 4pou
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 472 total comparisons
# Finished processing pdb.
#
#
# 127.- Analyzing pdb 5dfw
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 548 total comparisons
# Finished processing pdb.
#
#
# 128.- Analyzing pdb 5dfv
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1154 total comparisons
# Finished processing pdb.
#
#
# 129.- Analyzing pdb 2aep
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 602 total comparisons
# Finished processing pdb.
#
#
# 130.- Analyzing pdb 2aeq
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 563 total comparisons
# Finished processing pdb.
#
#
# 131.- Analyzing pdb 1oay
# 27 total comparisons
# Finished processing pdb.
#
#
# 132.- Analyzing pdb 1oar
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 604 total comparisons
# Finished processing pdb.
#
#
# 133.- Analyzing pdb 1oau
# 'CA'
#
#
# 134.- Analyzing pdb 1nma
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 518 total comparisons
# Finished processing pdb.
#
#
# 135.- Analyzing pdb 4hlz
# 'D | C'
#
#
# 136.- Analyzing pdb 4kfz
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1243 total comparisons
# Finished processing pdb.
#
#
# 137.- Analyzing pdb 5kov
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2700 comparisons made so far.
# 2800 comparisons made so far.
# 2900 comparisons made so far.
# 3000 comparisons made so far.
# 3100 comparisons made so far.
# 3200 comparisons made so far.
# 3300 comparisons made so far.
# 3400 comparisons made so far.
# 3500 comparisons made so far.
# 3600 comparisons made so far.
# 3700 comparisons made so far.
# 3800 comparisons made so far.
# 3900 comparisons made so far.
# 4000 comparisons made so far.
# 4100 comparisons made so far.
# 4200 comparisons made so far.
# 4300 comparisons made so far.
# 4400 comparisons made so far.
# 4500 comparisons made so far.
# 4600 comparisons made so far.
# 4700 comparisons made so far.
# 4784 total comparisons
# Finished processing pdb.
#
#
# 138.- Analyzing pdb 6db9
# '  G'
#
#
# 139.- Analyzing pdb 3g6d
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 526 total comparisons
# Finished processing pdb.
#
#
# 140.- Analyzing pdb 3g6j
# 'B | A'
#
#
# 141.- Analyzing pdb 4lmq
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 997 total comparisons
# Finished processing pdb.
#
#
# 142.- Analyzing pdb 2fjh
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 950 total comparisons
# Finished processing pdb.
#
#
# 143.- Analyzing pdb 2fjg
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1219 total comparisons
# Finished processing pdb.
#
#
# 144.- Analyzing pdb 2y07
# 100 comparisons made so far.
# 144 total comparisons
# Finished processing pdb.
#
#
# 145.- Analyzing pdb 2y06
# 'CA'
#
#
# 146.- Analyzing pdb 5mzv
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 511 total comparisons
# Finished processing pdb.
#
#
# 147.- Analyzing pdb 2oqj
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1127 total comparisons
# Finished processing pdb.
#
#
# 148.- Analyzing pdb 1i8m
# ' DT'
#
#
# 149.- Analyzing pdb 5lhn
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 634 total comparisons
# Finished processing pdb.
#
#
# 150.- Analyzing pdb 4j4p
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1567 total comparisons
# Finished processing pdb.
#
#
# Analyzed 150 PDBs so far.
# 151.- Analyzing pdb 6fe4
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1856 total comparisons
# Finished processing pdb.
#
#
# 152.- Analyzing pdb 5e2v
# 100 comparisons made so far.
# 164 total comparisons
# Finished processing pdb.
#
#
# 153.- Analyzing pdb 5e2w
# 100 comparisons made so far.
# 122 total comparisons
# Finished processing pdb.
#
#
# 154.- Analyzing pdb 5cin
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 359 total comparisons
# Finished processing pdb.
#
#
# 155.- Analyzing pdb 5cil
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 342 total comparisons
# Finished processing pdb.
#
#
# 156.- Analyzing pdb 1hh6
# 100 comparisons made so far.
# 200 comparisons made so far.
# 274 total comparisons
# Finished processing pdb.
#
#
# 157.- Analyzing pdb 3lhp
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1045 total comparisons
# Finished processing pdb.
#
#
# 158.- Analyzing pdb 3lh2
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2531 total comparisons
# Finished processing pdb.
#
#
# 159.- Analyzing pdb 1tet
# 100 comparisons made so far.
# 'CA'
#
#
# 160.- Analyzing pdb 6mlk
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 631 total comparisons
# Finished processing pdb.
#
#
# 161.- Analyzing pdb 5vyf
# 100 comparisons made so far.
# 200 comparisons made so far.
# ...
# 300 comparisons made so far.
# 400 comparisons made so far.
# 424 total comparisons
# Finished processing pdb.
#
#
# 592.- Analyzing pdb 6ejm
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1600 total comparisons
# Finished processing pdb.
#
#
# 593.- Analyzing pdb 6ejg
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 992 total comparisons
# Finished processing pdb.
#
#
# 594.- Analyzing pdb 3t2n
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1108 total comparisons
# Finished processing pdb.
#
#
# 595.- Analyzing pdb 5imk
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 511 total comparisons
# Finished processing pdb.
#
#
# 596.- Analyzing pdb 5imm
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 496 total comparisons
# Finished processing pdb.
#
#
# 597.- Analyzing pdb 4r3s
# 100 comparisons made so far.
# 200 comparisons made so far.
# 266 total comparisons
# Finished processing pdb.
#
#
# 598.- Analyzing pdb 4bkl
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 634 total comparisons
# Finished processing pdb.
#
#
# 599.- Analyzing pdb 3ma9
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 738 total comparisons
# Finished processing pdb.
#
#
# 600.- Analyzing pdb 2nz9
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1274 total comparisons
# Finished processing pdb.
#
#
# Analyzed 600 PDBs so far.
# 601.- Analyzing pdb 5anm
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 811 total comparisons
# Finished processing pdb.
#
#
# 602.- Analyzing pdb 6ddm
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 544 total comparisons
# Finished processing pdb.
#
#
# 603.- Analyzing pdb 3mac
# 'CA'
#
#
# 604.- Analyzing pdb 3o6l
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 322 total comparisons
# Finished processing pdb.
#
#
# 605.- Analyzing pdb 3o6m
# 100 comparisons made so far.
# 200 comparisons made so far.
# 251 total comparisons
# Finished processing pdb.
#
#
# 606.- Analyzing pdb 1cz8
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1103 total comparisons
# Finished processing pdb.
#
#
# 607.- Analyzing pdb 3fku
# 'H | G'
#
#
# 608.- Analyzing pdb 6b9j
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1390 total comparisons
# Finished processing pdb.
#
#
# 609.- Analyzing pdb 5yoy
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2700 comparisons made so far.
# 2800 comparisons made so far.
# 2900 comparisons made so far.
# 3000 comparisons made so far.
# 3100 comparisons made so far.
# 3200 comparisons made so far.
# 3300 comparisons made so far.
# 3400 comparisons made so far.
# 3500 comparisons made so far.
# 3600 comparisons made so far.
# 3700 comparisons made so far.
# 3800 comparisons made so far.
# 3900 comparisons made so far.
# 4000 comparisons made so far.
# 4049 total comparisons
# Finished processing pdb.
#
#
# 610.- Analyzing pdb 4n8c
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 658 total comparisons
# Finished processing pdb.
#
#
# 611.- Analyzing pdb 5u4m
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 614 total comparisons
# Finished processing pdb.
#
#
# 612.- Analyzing pdb 4i3r
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 525 total comparisons
# Finished processing pdb.
#
#
# 613.- Analyzing pdb 5fv2
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 979 total comparisons
# Finished processing pdb.
#
#
# 614.- Analyzing pdb 4x7s
# 0 total comparisons
# Finished processing pdb.
# Empty temp_df with pdb 4x7s
#
#
# 615.- Analyzing pdb 3hae
# 'A | C'
#
#
# 616.- Analyzing pdb 3sqo
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 497 total comparisons
# Finished processing pdb.
#
#
# 617.- Analyzing pdb 5f3b
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1037 total comparisons
# Finished processing pdb.
#
#
# 618.- Analyzing pdb 4hkx
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 646 total comparisons
# Finished processing pdb.
#
#
# 619.- Analyzing pdb 5m2i
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2700 comparisons made so far.
# 2800 comparisons made so far.
# 2900 comparisons made so far.
# 3000 comparisons made so far.
# 3100 comparisons made so far.
# 3200 comparisons made so far.
# 3300 comparisons made so far.
# 3400 comparisons made so far.
# 3500 comparisons made so far.
# 3600 comparisons made so far.
# 3700 comparisons made so far.
# 3800 comparisons made so far.
# 3900 comparisons made so far.
# 4000 comparisons made so far.
# 4100 comparisons made so far.
# 4200 comparisons made so far.
# 4300 comparisons made so far.
# 4390 total comparisons
# Finished processing pdb.
#
#
# 620.- Analyzing pdb 5m2j
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 361 total comparisons
# Finished processing pdb.
#
#
# 621.- Analyzing pdb 5m2m
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1300 comparisons made so far.
# 1400 comparisons made so far.
# 1500 comparisons made so far.
# 1600 comparisons made so far.
# 1700 comparisons made so far.
# 1800 comparisons made so far.
# 1900 comparisons made so far.
# 2000 comparisons made so far.
# 2100 comparisons made so far.
# 2200 comparisons made so far.
# 2300 comparisons made so far.
# 2400 comparisons made so far.
# 2500 comparisons made so far.
# 2600 comparisons made so far.
# 2700 comparisons made so far.
# 2706 total comparisons
# Finished processing pdb.
#
#
# 622.- Analyzing pdb 4jlr
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 882 total comparisons
# Finished processing pdb.
#
#
# 623.- Analyzing pdb 5sy8
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 495 total comparisons
# Finished processing pdb.
#
#
# 624.- Analyzing pdb 6axp
# 0 total comparisons
# Finished processing pdb.
# Empty temp_df with pdb 6axp
#
#
# 625.- Analyzing pdb 6axl
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 903 total comparisons
# Finished processing pdb.
#
#
# 626.- Analyzing pdb 6axk
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 320 total comparisons
# Finished processing pdb.
#
#
# 627.- Analyzing pdb 4qyo
# 100 comparisons made so far.
# 200 comparisons made so far.
# 228 total comparisons
# Finished processing pdb.
#
#
# 628.- Analyzing pdb 4qy8
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 324 total comparisons
# Finished processing pdb.
#
#
# 629.- Analyzing pdb 6a0z
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 673 total comparisons
# Finished processing pdb.
#
#
# 630.- Analyzing pdb 6bf4
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 522 total comparisons
# Finished processing pdb.
#
#
# 631.- Analyzing pdb 3r1g
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 589 total comparisons
# Finished processing pdb.
#
#
# 632.- Analyzing pdb 5t29
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 472 total comparisons
# Finished processing pdb.
#
#
# 633.- Analyzing pdb 4i18
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 'CA'
#
#
# 634.- Analyzing pdb 2qhr
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 306 total comparisons
# Finished processing pdb.
#
#
# 635.- Analyzing pdb 1jrh
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 381 total comparisons
# Finished processing pdb.
#
#
# 636.- Analyzing pdb 2j5l
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 487 total comparisons
# Finished processing pdb.
#
#
# 637.- Analyzing pdb 5tzt
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 625 total comparisons
# Finished processing pdb.
#
#
# 638.- Analyzing pdb 5tz2
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 545 total comparisons
# Finished processing pdb.
#
#
# 639.- Analyzing pdb 4wv1
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1100 comparisons made so far.
# 1200 comparisons made so far.
# 1205 total comparisons
# Finished processing pdb.
#
#
# 640.- Analyzing pdb 4d9r
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1011 total comparisons
# Finished processing pdb.
#
#
# 641.- Analyzing pdb 1eo8
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 413 total comparisons
# Finished processing pdb.
#
#
# 642.- Analyzing pdb 3ux9
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 912 total comparisons
# Finished processing pdb.
#
#
# 643.- Analyzing pdb 3mxw
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 442 total comparisons
# Finished processing pdb.
#
#
# 644.- Analyzing pdb 4d9q
# 100 comparisons made so far.
# 200 comparisons made so far.
# 300 comparisons made so far.
# 400 comparisons made so far.
# 500 comparisons made so far.
# 600 comparisons made so far.
# 700 comparisons made so far.
# 800 comparisons made so far.
# 900 comparisons made so far.
# 1000 comparisons made so far.
# 1015 total comparisons
# Finished processing pdb.
#
#
# 645.- Analyzing pdb 6azl
# 0 total comparisons
# Finished processing pdb.
# Empty temp_df with pdb 6azl
#
#
# 646.- Analyzing pdb 6azk
# 0 total comparisons
# Finished processing pdb.
# Empty temp_df with pdb 6azk

# %% [markdown]
# These are the PDBs that were not processed due to errors.

# %%
pending_pdbs_df.error.unique()
# Out:
# array([KeyError(' DT'), KeyError('CA'), KeyError('CA'), KeyError('CA'),
#        KeyError('CA'), KeyError('  G'), KeyError('CA'), KeyError('CA'),
#        KeyError('D | C'), KeyError('  G'), KeyError('B | A'),
#        KeyError('CA'), KeyError(' DT'), KeyError('CA'), KeyError('CA'),
#        KeyError('CA'), KeyError('CA'),
#        IndexError('Too many levels: Index has only 1 level, not 2'),
#        KeyError(nan), KeyError('CA'), KeyError('CA'), KeyError('CA'),
#        KeyError('CA'), KeyError('CA'), KeyError('A | C'), KeyError('  G'),
#        KeyError('CA'), KeyError('D | C'), KeyError('CA'), KeyError('CA'),
#        KeyError('B | A'), KeyError('CA'), KeyError('  G'), KeyError(nan),
#        KeyError(nan), KeyError('Y | X'), KeyError('CA'), KeyError('CA'),
#        KeyError('CA'), KeyError('CA'), KeyError('CA'), KeyError('CA'),
#        KeyError('D | F'), KeyError('UNK'), KeyError('UNK'),
#        KeyError('UNK'), KeyError(nan), KeyError(nan), KeyError(' DC'),
#        KeyError('  G'), KeyError('  G'), KeyError('E | G'),
#        IndexError('Too many levels: Index has only 1 level, not 2'),
#        KeyError(nan), KeyError(nan), KeyError(nan), KeyError('CA'),
#        KeyError('H | G'), KeyError('A | C'), KeyError('CA')], dtype=object)

# %% [markdown]
# # 3. Check closest residues

# %%
closest_ress_df = pd.read_csv('closest_residues.csv')

# %%
len(closest_ress_df)
# Out:
# 120472

# %%
closest_ress_df.head(20)
# Out:
#    ab_label ab_res  ab_seqid ab_letter ab_letter_seqid   cdr  ab_list_idx  \
# 0         H    TYR        28         Y            Y-28  CDR1           26
# 1         H    TYR        28         Y            Y-28  CDR1           26
# 2         H    TYR        28         Y            Y-28  CDR1           26
# 3         H    THR        29         T            T-29  CDR1           27
# 4         H    THR        29         T            T-29  CDR1           27
# 5         H    THR        29         T            T-29  CDR1           27
# 6         H    PHE        30         F            F-30  CDR1           28
# 7         H    PHE        30         F            F-30  CDR1           28
# 8         H    PHE        30         F            F-30  CDR1           28
# 9         H    THR        35         T            T-35  CDR1           29
# 10        H    THR        35         T            T-35  CDR1           29
# 11        H    THR        35         T            T-35  CDR1           29
# 12        H    ASN        36         N            N-36  CDR1           30
# 13        H    ASN        36         N            N-36  CDR1           30
# 14        H    ASN        36         N            N-36  CDR1           30
# 15        H    ASN        36         N            N-36  CDR1           30
# 16        H    TYR        37         Y            Y-37  CDR1           31
# 17        H    TYR        37         Y            Y-37  CDR1           31
# 18        H    TYR        37         Y            Y-37  CDR1           31
# 19        H    GLY        38         G            G-38  CDR1           32
#
#    ag_label ag_res  ag_seqid ag_letter ag_letter_seqid  ag_list_idx  \
# 0         W    GLN        79         Q            Q-79           65
# 1         W    MET        81         M            M-81           67
# 2         W    GLN        89         Q            Q-89           75
# 3         V    TYR        21         Y            Y-21            7
# 4         W    LYS        48         K            K-48           34
# 5         W    ILE        80         I            I-80           66
# 6         V    PHE        17         F            F-17            3
# 7         W    GLY        88         G            G-88           74
# 8         W    GLY        92         G            G-92           78
# 9         V    LYS        16         K            K-16            2
# 10        W    PHE        47         F            F-47           33
# 11        W    PRO        49         P            P-49           35
# 12        V    VAL        15         V            V-15            1
# 13        V    GLN        22         Q            Q-22            8
# 14        W    PRO        85         P            P-85           71
# 15        W    GLN        87         Q            Q-87           73
# 16        V    LYS        16         K            K-16            2
# 17        W    ILE        46         I            I-46           32
# 18        W    PRO        49         P            P-49           35
# 19        W    TYR        45         Y            Y-45           31
#
#      distance ab_ress_seqid ag_ress_seqid   pdb
# 0   14.298218        TYR-28        GLN-79  1bj1
# 1   14.552553        TYR-28        MET-81  1bj1
# 2   14.830989        TYR-28        GLN-89  1bj1
# 3   14.333929        THR-29        TYR-21  1bj1
# 4   14.978921        THR-29        LYS-48  1bj1
# 5   13.960920        THR-29        ILE-80  1bj1
# 6   13.223936        PHE-30        PHE-17  1bj1
# 7   14.412254        PHE-30        GLY-88  1bj1
# 8   14.345451        PHE-30        GLY-92  1bj1
# 9   14.343775        THR-35        LYS-16  1bj1
# 10  14.343426        THR-35        PHE-47  1bj1
# 11  14.211858        THR-35        PRO-49  1bj1
# 12  14.960812        ASN-36        VAL-15  1bj1
# 13  14.886013        ASN-36        GLN-22  1bj1
# 14  14.987860        ASN-36        PRO-85  1bj1
# 15  14.858545        ASN-36        GLN-87  1bj1
# 16  14.563991        TYR-37        LYS-16  1bj1
# 17  14.133194        TYR-37        ILE-46  1bj1
# 18  14.963491        TYR-37        PRO-49  1bj1
# 19  14.663525        GLY-38        TYR-45  1bj1

# %%
closest_ress_df.groupby(['pdb','ab_ress_seqid']).count()
# Out:
#                     ab_label  ab_res  ab_seqid  ab_letter  ab_letter_seqid  \
# pdb  ab_ress_seqid
# 1bj1 ALA-105               6       6         6          6                6
#      ASN-36                6       6         6          6                6
#      ASN-57                6       6         6          6                6
#      ASP-116               6       6         6          6                6
#      GLN-105               3       3         3          3                3
# ...                      ...     ...       ...        ...              ...
# 6mnf SER-59                6       6         6          6                6
#      SER-62                6       6         6          6                6
#      THR-58                4       4         4          4                4
#      THR-63                5       5         5          5                5
#      TYR-64                5       5         5          5                5
#
#                     cdr  ab_list_idx  ag_label  ag_res  ag_seqid  ag_letter  \
# pdb  ab_ress_seqid
# 1bj1 ALA-105          6            6         6       6         6          6
#      ASN-36           6            6         6       6         6          6
#      ASN-57           6            6         6       6         6          6
#      ASP-116          6            6         6       6         6          6
#      GLN-105          3            3         3       3         3          3
# ...                 ...          ...       ...     ...       ...        ...
# 6mnf SER-59           6            6         6       6         6          6
#      SER-62           6            6         6       6         6          6
#      THR-58           4            4         4       4         4          4
#      THR-63           5            5         5       5         5          5
#      TYR-64           5            5         5       5         5          5
#
#                     ag_letter_seqid  ag_list_idx  distance  ag_ress_seqid
# pdb  ab_ress_seqid
# 1bj1 ALA-105                      6            6         6              6
#      ASN-36                       6            6         6              6
#      ASN-57                       6            6         6              6
#      ASP-116                      6            6         6              6
#      GLN-105                      3            3         3              3
# ...                             ...          ...       ...            ...
# 6mnf SER-59                       6            6         6              6
#      SER-62                       6            6         6              6
#      THR-58                       4            4         4              4
#      THR-63                       5            5         5              5
#      TYR-64                       5            5         5              5
#
# [22272 rows x 15 columns]
